# %%
import pandas as pd

# %%
pd.read_csv('train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.DataFrame()

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 21)

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# WikiId         float64
# Name_wiki       object
# Age_wiki       float64
# Hometown        object
# Boarded         object
# Destination     object
# Lifeboat        object
# Body            object
# Class          float64
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare       WikiId    Age_wiki       Class
# count  891.000000  891.000000   889.000000  887.000000  889.000000
# mean     0.381594   32.204208   665.466817   29.322063    2.307087
# std      0.806057   49.693429   380.796997   13.930089    0.837713
# min      0.000000    0.000000     1.000000    0.420000    1.000000
# ...

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare       WikiId    Age_wiki       Class
# count  891.000000  891.000000   889.000000  887.000000  889.000000
# mean     0.381594   32.204208   665.466817   29.322063    2.307087
# std      0.806057   49.693429   380.796997   13.930089    0.837713
# min      0.000000    0.000000     1.000000    0.420000    1.000000
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# WikiId           2
# Name_wiki        2
# Age_wiki         4
# Hometown         2
# Boarded          2
# Destination      2
# Lifeboat       546
# Body           804
# Class            2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
number_of_elements = len(df['Age'])
print("Number of elements: ", number_of_elements)
#number of elements per category
print(df['Age'].value_counts())
#Replace and display the values
df['Age'].fillna('G6',inplace=True)
df.tail()
# Out:
# Number of elements:  891
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 30.000000     25
#             ...
# 53.000000      1
# 55.500000      1
# 0.920000       1
# 24.500000      1
# 70.500000      1
# Name: Age, Length: 89, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# ...

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Cabin'])
print("Number of elements: ", number_of_elements)
#number of elements per category
print(df['Cabin'].value_counts())
#Replace and display the values
df['Cabin'].fillna('G6',inplace=True)
df.tail()
# Out:
# Number of elements:  891
# B96 B98        691
# G6               4
# C23 C25 C27      4
# C22 C26          3
# E101             3
#               ...
# E40              1
# C148             1
# A31              1
# E58              1
# C86              1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# ...

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Embarked'])
print("Number of elements: ", number_of_elements)
#number of elements per category
print(df['Embarked'].value_counts())
#Replace and display the values
df['Embarked'].fillna('G6',inplace=True)
df.tail()
# Out:
# Number of elements:  891
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# 888  female  29.699118      1      2  W./C. 6607  23.45  ...        S  910.0
# 889    male  26.000000      0      0      111369  30.00  ...        C   28.0
# ...

# %%
df['WikiId'].fillna(df['WikiId'].mean(),inplace=True)

# %%
number_of_elements = len(df['WikiId'])
print("WikiId: ", number_of_elements)
#number of elements per category
print(df['WikiId'].value_counts())
#Replace and display the values
df['WikiId'].fillna('G6',inplace=True)
df.tail()
# Out:
# WikiId:  891
# 665.466817     2
# 743.000000     1
# 121.000000     1
# 809.000000     1
# 175.000000     1
#               ..
# 794.000000     1
# 358.000000     1
# 242.000000     1
# 325.000000     1
# 1211.000000    1
# Name: WikiId, Length: 890, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# ...

# %%
df['Age_wiki'].fillna(df['Age_wiki'].mean(),inplace=True)

# %%
number_of_elements = len(df['Age_wiki'])
print("Age_wiki: ", number_of_elements)
#number of elements per category
print(df['Age_wiki'].value_counts())
#Replace and display the values
df['Age_wiki'].fillna('G6',inplace=True)
df.tail()
# Out:
# Age_wiki:  891
# 22.00    39
# 19.00    36
# 24.00    34
# 28.00    32
# 29.00    31
#          ..
# 70.00     1
# 0.83      1
# 74.00     1
# 0.92      1
# 0.42      1
# Name: Age_wiki, Length: 74, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# ...

# %%
df[].fillna(df['Hometown'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Hometown'])
print("Hometown: ", number_of_elements)
#number of elements per category
print(df['Hometown'].value_counts())
#Replace and display the values
df['Hometown'].fillna('G6',inplace=True)
df.tail()
# Out:
# Hometown:  891
# New York, New York, US                        50
# London, England                               31
# London, England, UK                           23
# Paris, France                                 16
# Unknown, Bulgaria                             13
#                                               ..
# Limerick, Limerick, Ireland                    1
# Effington Rut, South Dakota, US                1
# Weston-super-Mare, North Somerset, England     1
# Wallasey, Merseyside, England, UK              1
# San Francisco, California, US                  1
# Name: Hometown, Length: 437, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# ...

# %%
df['Name_wiki'].fillna(df['Name_wiki'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Name_wiki'])
print("Name_wiki: ", number_of_elements)
#number of elements per category
print(df['Name_wiki'].value_counts())
#Replace and display the values
df['Name_wiki'].fillna('G6',inplace=True)
df.tail()
# Out:
# Name_wiki:  891
# Green, Mr. George Henry                      1
# Goldschmidt, Mr. George B.                   1
# Hart, Mr. Henry John                         1
# Weisz, Mrs. Mathilde Françoise (née Pëde)    1
# Dooley, Mr. Patrick J.                       1
#                                             ..
# Cook, Mr. Jacob (Kukk, Mr. Jakob?)           1
# Dodge, Master Washington, Jr.                1
# Butrus-Youssef, Mrs. Katarin (née Rizk)      1
# Davies, Mr. Alfred John                      1
# Jussila, Miss Mari Aina                      1
# Name: Name_wiki, Length: 889, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# ...

# %%
df['Boarded'].fillna(df['Boarded'].mode(),inplace=True)

# %%
number_of_elements = len(df['Boarded'])
print("Boarded: ", number_of_elements)
#number of elements per category
print(df['Boarded'].value_counts())
#Replace and display the values
df['Boarded'].fillna('G6',inplace=True)
df.tail()
# Out:
# Boarded:  891
# Southampton    638
# Cherbourg      166
# Queenstown      76
# Belfast          9
# Name: Boarded, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# 888  female  29.699118      1      2  W./C. 6607  23.45  ...        S  910.0
# ...

# %%
df['Destination'].fillna(df['Destination'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Destination'])
print("Destination: ", number_of_elements)
#number of elements per category
print(df['Destination'].value_counts())
#Replace and display the values
df['Destination'].fillna('G6',inplace=True)
df.tail()
# Out:
# Destination:  891
# New York City                168
# New York, New York, US        90
# Chicago, Illinois, US         58
# Montreal, Quebec, Canada      25
# Detroit, Michigan, US         22
#                             ...
# Peoria, Illinois, US           1
# Palmer, Massachusetts, US      1
# Stamford, Connecticut US       1
# Clear Creek, Colorado, US      1
# Canastota, New York, US        1
# Name: Destination, Length: 234, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Lifeboat'].fillna(df['Lifeboat'].mean(),inplace=True)

# %%
number_of_elements = len(df['Lifeboat'])
print("Lifeboat: ", number_of_elements)
#number of elements per category
print(df['Lifeboat'].value_counts())
#Replace and display the values
df['Lifeboat'].fillna('G6',inplace=True)
df.tail()
# Out:
# Lifeboat:  891
# C      28
# 15     28
# 13     26
# 14     22
# 4      22
# 5      21
# 3      21
# 9      20
# 10     18
# 16     18
# 8      17
# 6      16
# 11     16
# D      14
# 12     12
# 7      11
# ?      10
# 2       8
# B       7
# A       6
# 1       3
# 14?     1
# Name: Lifeboat, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# ...

# %%
df['Body'].fillna(df['Body'].mode()[0],inplace=True)

# %%
number_of_elements = len(df['Body'])
print:("Body:" , number_of_elements)
#number of elements per category
print(df['Body'].value_counts())
#Replace and display the values
df['Body'].fillna('G6',inplace=True)
df.tail()
# Out:
# 101MB    805
# 174MB      1
# 19MB       1
# 263MB      1
# 166MB      1
#         ...
# 172MB      1
# 332O       1
# 149MB      1
# 312M       1
# 147MB      1
# Name: Body, Length: 87, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# ...

# %%
df['Class'].fillna(df['Class'].mean(),inplace=True)

# %%
number_of_elements = len(df['Class'])
print("Class: ", number_of_elements)
#number of elements per category
print(df['Class'].value_counts())
#Replace and display the values
df['Class'].fillna('G6',inplace=True)
df.tail()
# Out:
# Class:  891
# 3.000000    490
# 1.000000    217
# 2.000000    182
# 2.307087      2
# Name: Class, dtype: int64
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# 887          888       1.0       1              Graham, Miss. Margaret Edith
# 888          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1.0       1                     Behr, Mr. Karl Howell
# 890          891       0.0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare  ... Embarked WikiId  \
# 886    male  27.000000      0      0      211536  13.00  ...        S  514.0
# 887  female  19.000000      0      0      112053  30.00  ...        S  137.0
# 888  female  29.699118      1      2  W./C. 6607  23.45  ...        S  910.0
# 889    male  26.000000      0      0      111369  30.00  ...        C   28.0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# WikiId         0
# Name_wiki      0
# Age_wiki       0
# Hometown       0
# Boarded        0
# Destination    0
# Lifeboat       0
# Body           0
# Class          0
# dtype: int64

# %%
import pandas as pd 
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv')

# %%
grid = sns.FacetGrid(df, row="Sex", size=2.2, aspect=1.6)
grid.map(sns.barplot, "Age", alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g=sns.FacetGrid(df, col='Sex')
g.map(plt.hist,'Age', bins=20)

# %%
df = pd.read_csv('train.csv', encoding = "ISO8859-1")
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
g=sns.FacetGrid(df, col='Sex')
g.map(plt.hist,'Age', bins=10)

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
grid = sns.FacetGrid(df, col='Survived', row='Pclass', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(df['Title'], df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Unique')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4  Unique  0.347826

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Unique": 5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  WikiId  \
# 0      0   7.2500        S   691.0
# 1      0  71.2833        C    90.0
# 2      0   7.9250        S   865.0
# 3      0  53.1000        S   127.0
# 4      0   8.0500        S   627.0
#
#                                      Name_wiki  Age_wiki  \
# ...

# %%
df =df.drop(['Name', 'PassengerId'], axis=1)
combine = [df]
df.shape
# Out:
# (891, 18)

# %%
grid = sns.FacetGrid(df, col='Survived', row='Title', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
grid = sns.FacetGrid(df, col='Survived', row='Title', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Sex', alpha=.5, bins=20)
grid.add_legend();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1

df[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000
